# %% [markdown]
# Рогович Татьяна
#
# # Анализ данных  в Python (политология)
#
# ## Spider Chart в Plotly
#
# ##### Занятия 15-16 | 12.11.2019

# %% [markdown]
# Есть такой вид графика radarplot (он же Spiderchart), который позволяет нам сравнивать наблюдения по нескольким измерениям.
#
# https://www.data-to-viz.com/caveat/spider.html
#
# https://python-graph-gallery.com/390-basic-radar-chart/

# %% [markdown]
# Давайте поработаем с таким датасетом: у нас есть даннные, где наблюдение это страна, а признак - некоторый политико-экономический индекс.

# %% [markdown]
# Ссылка на исследование:
# https://github.com/rogovich/2019-2020_PolSci_Data_Analysis_in_Python/blob/master/11week_Viz_Spiderchart_Scraping/GivingCreditWhereItsDue_LazardResearch_en.pdf

# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/rogovich/2019-2020_PolSci_Data_Analysis_in_Python/master/11week_Viz_Spiderchart_Scraping/countries_ranking.txt', sep = ',', encoding = 'utf8')

# %%
df.tail()
# Out:
#        Country  Index Spread  Voice & Accountability  Political Stability  \
# 60    Suriname           655                      17                   16
# 61     Ecuador           705                      39                   31
# 62      Belize           732                      10                   22
# 63  Mozambique          1770                      40                   43
# 64   Venezuela          2457                      58                   54
#
#     Govt. Effectiveness  Regulatory Quality  Rule of Law  \
# 60                   43                  54           29
# 61                   46                  63           60
# 62                   54                  47           51
# 63                   57                  48           56
# 64                   64                  65           65
#
#     Control of Corruption  Corruption percetion  Ease of Doing Business  \
# 60                     43                    17                      58
# 61                     46                    48                      46
# 62                     21                    65                      45
# 63                     54                    59                      53
# 64                     63                    63                      65
#
#     Human Dev. Index  Global Compet. Index  Eviron. Performance Index  \
# 60                37                    62                         40
# 61                31                    39                         44
# 62                39                    63                         29
# 63                65                    61                         65
# 64                21                    60                         20
#
#     Fragile States Index  UN World Risk Index  Freedom of the Press Index
# 60                    21                   51                           9
# 61                    39                   48                          48
# 62                    18                   37                           8
# 63                    55                   52                          28
# 64                    49                   27                          59

# %%
df.columns
# Out:
# Index(['Country', 'Index Spread', 'Voice & Accountability',
#        'Political Stability', 'Govt. Effectiveness', 'Regulatory Quality',
#        'Rule of Law', 'Control of Corruption', 'Corruption percetion',
#        'Ease of Doing Business', 'Human Dev. Index', 'Global Compet. Index',
#        'Eviron. Performance Index', 'Fragile States Index',
#        'UN World Risk Index', 'Freedom of the Press Index'],
#       dtype='object')

# %%
df[df['Country']=='Slovakia'].loc[:, "Voice & Accountability":]
# Out:
#    Voice & Accountability  Political Stability  Govt. Effectiveness  \
# 0                       6                    2                    5
#
#    Regulatory Quality  Rule of Law  Control of Corruption  \
# 0                   6            7                     13
#
#    Corruption percetion  Ease of Doing Business  Human Dev. Index  \
# 0                     9                       6                 4
#
#    Global Compet. Index  Eviron. Performance Index  Fragile States Index  \
# 0                    23                          4                     5
#
#    UN World Risk Index  Freedom of the Press Index
# 0                    8                           7

# %%
df.loc[:, "Voice & Accountability":].describe()
# Out:
#        Voice & Accountability  Political Stability  Govt. Effectiveness  \
# count                65.00000             65.00000             65.00000
# mean                 33.00000             33.00000             33.00000
# std                  18.90767             18.90767             18.90767
# min                   1.00000              1.00000              1.00000
# 25%                  17.00000             17.00000             17.00000
# 50%                  33.00000             33.00000             33.00000
# 75%                  49.00000             49.00000             49.00000
# max                  65.00000             65.00000             65.00000
#
#        Regulatory Quality  Rule of Law  Control of Corruption  \
# count            65.00000     65.00000               65.00000
# mean             33.00000     33.00000               33.00000
# std              18.90767     18.90767               18.90767
# min               1.00000      1.00000                1.00000
# 25%              17.00000     17.00000               17.00000
# 50%              33.00000     33.00000               33.00000
# 75%              49.00000     49.00000               49.00000
# max              65.00000     65.00000               65.00000
#
#        Corruption percetion  Ease of Doing Business  Human Dev. Index  \
# count              65.00000                65.00000          65.00000
# mean               33.00000                33.00000          33.00000
# std                18.90767                18.90767          18.90767
# min                 1.00000                 1.00000           1.00000
# 25%                17.00000                17.00000          17.00000
# 50%                33.00000                33.00000          33.00000
# 75%                49.00000                49.00000          49.00000
# max                65.00000                65.00000          65.00000
#
#        Global Compet. Index  Eviron. Performance Index  Fragile States Index  \
# count              65.00000                   65.00000              65.00000
# mean               33.00000                   33.00000              33.00000
# std                18.90767                   18.90767              18.90767
# min                 1.00000                    1.00000               1.00000
# 25%                17.00000                   17.00000              17.00000
# 50%                33.00000                   33.00000              33.00000
# 75%                49.00000                   49.00000              49.00000
# max                65.00000                   65.00000              65.00000
#
#        UN World Risk Index  Freedom of the Press Index
# count             65.00000                    65.00000
# mean              33.00000                    33.00000
# std               18.90767                    18.90767
# min                1.00000                     1.00000
# 25%               17.00000                    17.00000
# 50%               33.00000                    33.00000
# 75%               49.00000                    49.00000
# max               65.00000                    65.00000

# %% [markdown]
# Мы хотим сравнивать страны по этим индексам. Для такого графика как Radarplot нам важно, чтобы индексы были стандартизированы. Здесь этой проблемы нет, потому что наши данные - это ранг стран. Но мы можем и стандартирозовать всю эту историю к другой шкале: например, от 0 до 1.
#
# Для этого из модуля sklearn импортируем модуль предобработки данных.

# %%
from sklearn import preprocessing

# %%
x = df.loc[:, "Voice & Accountability":].values # достаем матрицу наших значений
x
# Out:
# array([[ 6,  2,  5,  6,  7, 13,  9,  6,  4, 23,  4,  5,  8,  7],
#        [ 3,  3,  6,  4,  3,  5,  3,  5,  1,  5, 10,  2,  6, 13],
#        [ 5,  5,  1,  2,  2,  6,  4,  3,  2,  4,  3,  4,  3,  3],
#        [ 7, 11,  2,  3,  4,  7,  6,  1,  6, 12,  2,  7,  7,  6],
#        [29, 48, 22, 28, 35, 33, 37, 38, 45, 17, 27, 52, 65, 23],
#        [12,  4,  9,  8, 11, 14, 12, 11,  5, 26,  5, 11, 21, 22],
#        [19, 52, 23, 43, 20, 29, 24, 52, 54,  7, 61, 45, 39, 21],
#        [ 4, 13,  3,  1,  1,  2,  2, 17,  3,  3, 17,  3, 59, 10],
#        [41, 18,  4,  7,  6,  8, 10,  4, 14,  1, 24, 19, 32, 52],
#        [18, 17, 28,  9, 15, 17, 14,  8, 10, 21,  8, 12, 26, 16],
#        [65, 41, 10, 39, 33, 24, 23, 28, 32,  2, 49, 36, 33, 64],
#        [24, 15, 21, 23, 23, 22, 20, 14, 18, 38, 15, 29, 43, 29],
#        [27, 39, 40, 11, 44, 45, 38, 16, 30, 25, 31, 30, 38, 24],
#        [14, 12, 13, 16, 24, 27, 27, 25, 15,  9, 16, 13, 45, 18],
#        [15, 10,  8, 17, 13, 11, 11, 12,  7, 30,  1, 10, 13, 17],
#        [63, 25, 25, 49, 31, 36, 43, 30, 44, 19, 58, 25, 61, 61],
#        [56, 55, 34, 51, 50, 56, 54, 10,  9, 10,  7, 48, 12, 60],
#        [50, 36, 30, 32, 22, 23, 31, 23, 50, 27, 25, 34, 35, 47],
#        [28, 45, 36, 35, 38, 38, 32, 33, 43,  8, 47, 37, 54, 30],
#        [ 2,  1,  7, 13,  5,  1,  1, 32, 12, 29, 26,  1, 14,  4],
#        [44, 46, 55, 34, 59, 49, 57, 31, 52, 32, 37, 50, 64, 40],
#        [34, 56, 27, 14, 32, 25, 30, 15, 35, 20, 21, 47, 34, 38],
#        [33, 34, 52, 59, 63, 48, 45, 57, 47, 57, 33, 43, 18, 35],
#        [36, 26, 61, 38, 49, 58, 52, 41, 41, 54, 36, 33,  9, 41],
#        [ 9,  8, 15, 31, 14,  9,  8, 42, 51, 35, 34, 27, 22, 11],
#        [59, 30, 29, 26, 36, 51, 53,  7, 13, 14, 30, 20, 10, 62],
#        [37, 51, 19, 15, 41, 50, 49, 13, 24, 13, 28, 24, 28, 45],
#        [25, 38, 11,  5, 12,  4,  7,  2, 19, 18, 50, 44, 31, 31],
#        [ 8, 33, 14, 19, 18, 16, 15, 26, 48, 11, 35, 23, 25, 15],
#        [20, 37, 35, 36, 27, 34, 25, 50, 26, 34, 14, 17, 15, 26],
#        [43, 57, 18, 18, 21, 19, 21, 24, 20, 16, 42, 41, 20, 57],
#        [16, 14, 17, 22, 25, 40, 36, 36, 16, 41, 23, 15, 47,  5],
#        [55,  6, 24, 10,  9, 12, 16, 21, 11, 24, 55,  9,  2, 53],
#        [22, 32, 45, 33, 26, 15, 18, 56, 62, 51, 53, 51, 55, 27],
#        [49, 35, 33, 20, 34, 37, 44,  9, 27, 33,  9, 22, 30, 43],
#        [51, 65, 53, 53, 53, 52, 46, 55, 58, 58, 62, 63, 41, 46],
#        [30, 19, 42, 29, 40, 53, 47, 39, 38, 40, 22, 26, 58, 20],
#        [47, 40, 60, 45, 57, 42, 51, 40, 53, 37, 38, 46, 56, 50],
#        [64, 47, 37, 37, 47, 55, 50, 20, 25,  6,  6, 40, 24, 65],
#        [11, 20, 16, 24, 28, 26, 26, 22, 34, 31, 19, 16, 60,  2],
#        [42, 27, 26, 30, 17, 28, 33, 44, 22, 28, 48, 54, 46, 42],
#        [52, 42, 20, 25, 10, 10, 13, 48, 29, 22, 32, 42, 17, 51],
#        [ 1,  9, 12, 12,  8,  3,  5, 18, 17, 15, 11,  6, 63,  1],
#        [46, 49, 51, 50, 48, 32, 41, 54, 63, 44, 56, 61, 53, 32],
#        [38, 58, 41, 41, 42, 60, 60, 34, 57, 43, 54, 62, 40, 39],
#        [54, 53, 59, 58, 58, 61, 61, 62, 61, 56, 60, 60, 57, 49],
#        [45, 63, 62, 57, 61, 62, 58, 63, 60, 59, 59, 64, 49, 33],
#        [26, 50, 32, 44, 19, 18, 22, 27, 36, 42, 18, 35, 23, 36],
#        [48, 61, 47, 40, 52, 57, 56, 51, 23, 45, 39, 56, 19, 37],
#        [57, 59, 58, 55, 43, 41, 42, 49, 42, 53, 45, 57,  1, 58],
#        [62, 60, 50, 62, 39, 31, 40, 59, 64, 50, 64, 59, 42, 63],
#        [23,  7, 44, 42, 37, 39, 28, 19, 33, 46, 51, 14,  5, 14],
#        [53, 23, 56, 56, 45, 47, 39, 60, 40, 49, 43, 31, 29, 54],
#        [21, 29, 31, 61, 55, 44, 34, 47,  8, 47, 12,  8, 11, 25],
#        [13, 24, 39, 27, 16, 20, 19, 43, 55, 52, 57, 28, 50, 12],
#        [35, 21, 49, 46, 30, 30, 29, 37, 56, 55, 46, 53, 44, 44],
#        [31, 28, 38, 21, 46, 35, 35, 35, 46, 48, 41, 32, 62, 19],
#        [32, 62, 48, 52, 54, 59, 55, 29, 28, 36, 13, 38,  4, 34],
#        [61, 64, 65, 64, 64, 64, 64, 61, 49, 65, 52, 65, 16, 55],
#        [60, 44, 63, 60, 62, 65, 62, 64, 59, 64, 63, 58, 36, 56],
#        [17, 16, 43, 54, 29, 43, 17, 58, 37, 62, 40, 21, 51,  9],
#        [39, 31, 46, 63, 60, 46, 48, 46, 31, 39, 44, 39, 48, 48],
#        [10, 22, 54, 47, 51, 21, 65, 45, 39, 63, 29, 18, 37,  8],
#        [40, 43, 57, 48, 56, 54, 59, 53, 65, 61, 65, 55, 52, 28],
#        [58, 54, 64, 65, 65, 63, 63, 65, 21, 60, 20, 49, 27, 59]],
#       dtype=int64)

# %% [markdown]
# Мы воспользуемся функцией MinMaxScaler(), которая стандартизирует признаки по колонке (самое низкое значение становится 0, самое большое 1)

# %%
min_max_scaler = preprocessing.MinMaxScaler() 
x_scaled = min_max_scaler.fit_transform(x)
# Out:
# C:\Users\rogov\Anaconda3\lib\site-packages\sklearn\utils\validation.py:475: DataConversionWarning:
#
# Data with input dtype int64 was converted to float64 by MinMaxScaler.

# %%
df.shape
# Out:
# (65, 16)

# %%
x_scaled.shape # вроде все получилось
# Out:
# (65, 14)

# %%
df_normalized = df.copy() # создаем копию данных

# %%
df_normalized.loc[:, "Voice & Accountability":] = x_scaled # перезаписываем оригинальные значение отшкалированными переменными

# %%
df_normalized.head(1)
# Out:
#     Country  Index Spread  Voice & Accountability  Political Stability  \
# 0  Slovakia            32                0.078125             0.015625
#
#    Govt. Effectiveness  Regulatory Quality  Rule of Law  \
# 0               0.0625            0.078125      0.09375
#
#    Control of Corruption  Corruption percetion  Ease of Doing Business  \
# 0                 0.1875                 0.125                0.078125
#
#    Human Dev. Index  Global Compet. Index  Eviron. Performance Index  \
# 0          0.046875               0.34375                   0.046875
#
#    Fragile States Index  UN World Risk Index  Freedom of the Press Index
# 0                0.0625             0.109375                     0.09375

# %%
df.head(1)
# Out:
#     Country  Index Spread  Voice & Accountability  Political Stability  \
# 0  Slovakia            32                       6                    2
#
#    Govt. Effectiveness  Regulatory Quality  Rule of Law  \
# 0                    5                   6            7
#
#    Control of Corruption  Corruption percetion  Ease of Doing Business  \
# 0                     13                     9                       6
#
#    Human Dev. Index  Global Compet. Index  Eviron. Performance Index  \
# 0                 4                    23                          4
#
#    Fragile States Index  UN World Risk Index  Freedom of the Press Index
# 0                     5                    8                           7

# %% [markdown]
# Было бы здорово, кроме страны нанести на график еще медиану.

# %%
df_normalized.median()
# Out:
# Index Spread                  300.0
# Voice & Accountability          0.5
# Political Stability             0.5
# Govt. Effectiveness             0.5
# Regulatory Quality              0.5
# Rule of Law                     0.5
# Control of Corruption           0.5
# Corruption percetion            0.5
# Ease of Doing Business          0.5
# Human Dev. Index                0.5
# Global Compet. Index            0.5
# Eviron. Performance Index       0.5
# Fragile States Index            0.5
# UN World Risk Index             0.5
# Freedom of the Press Index      0.5
# dtype: float64

# %% [markdown]
# Radarplot работает с векторами numpy. Поэтому давайте поймем, что мы будем ему отдавать.

# %%
df_normalized[df_normalized['Country'] == 'Slovakia'].loc[:,"Voice & Accountability":].values[0]
# Out:
# array([0.078125, 0.015625, 0.0625  , 0.078125, 0.09375 , 0.1875  ,
#        0.125   , 0.078125, 0.046875, 0.34375 , 0.046875, 0.0625  ,
#        0.109375, 0.09375 ])

# %% [markdown]
# Экспресс-график. А ниже построим в обычном синтаксисе с медианой.

# %%
import plotly.express as px

fig = px.line_polar(df_normalized, r=df_normalized.loc[:,"Voice & Accountability":].values[0], 
                    line_close=True, theta = df_normalized.columns[2:] )
fig.show()
# Out:
# <div>
#
#
#             <div id="1a509b61-88f6-4604-96ff-c2d742240ae5" class="plotly-graph-div" style="height:600px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1a509b61-88f6-4604-96ff-c2d742240ae5")) {
#                     Plotly.newPlot(
#                         '1a509b61-88f6-4604-96ff-c2d742240ae5',
#                         [{"hoverlabel": {"namelength": 0}, "hovertemplate": "r=%{r}<br>theta=%{theta}", "legendgroup": "", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "", "r": [0.078125, 0.015625, 0.0625, 0.078125, 0.09375, 0.1875, 0.125, 0.078125, 0.046875, 0.34375, 0.046875, 0.0625, 0.109375, 0.09375, 0.078125], "showlegend": false, "subplot": "polar", "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"height": 600, "legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "polar": {"angularaxis": {"direction": "clockwise", "rotation": 90}, "domain": {"x": [0.0, 0.98], "y": [0.0, 1.0]}}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpola ...

# %% [markdown]
# А теперь давайте вернемся к нашей неотнормированной шкале и добавим на график еще и середину (33 место).

# %%
import plotly
import plotly.graph_objs as go
from plotly.subplots import make_subplots


trace0 = go.Scatterpolar(
      r = df[df['Country'] == 'Slovakia'].loc[:,"Voice & Accountability":].values[0], # данные на шкалы 
      theta = df.columns[2:], # подписи шкал
      fill = 'toself', # заливка
      name = 'Slovakia'
    )
    
trace_median= go.Scatterpolar(
      r = df.loc[:,"Voice & Accountability":].median().values,
      theta = df.columns[2:],
      fill = 'none',
      name = 'Average'
    )

layout = go.Layout(
    template="plotly_dark",
    polar = dict(
    radialaxis = dict(
      visible = True,
      range = [1, 65]
    )
  ),
  showlegend = False
)

fig = go.Figure(data=[trace0, trace_median], layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="da701723-0c38-4992-90e9-d29a0784fa76" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("da701723-0c38-4992-90e9-d29a0784fa76")) {
#                     Plotly.newPlot(
#                         'da701723-0c38-4992-90e9-d29a0784fa76',
#                         [{"fill": "toself", "name": "Slovakia", "r": [6, 2, 5, 6, 7, 13, 9, 6, 4, 23, 4, 5, 8, 7], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index"], "type": "scatterpolar"}, {"fill": "none", "name": "Average", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...

# %% [markdown]
# Контур не замкнулся. Давайте схитрим и сделаем вид, что последня колонка называется как первая и содержит те же значения и Poltly построит их друг над другом.

# %%
col_names = list(df.columns)[2:]

# %%
col_names.append('Voice & Accountability')

# %%
df['Voice & Accountability 2'] = df['Voice & Accountability']

# %%
import plotly
import plotly.graph_objs as go


trace0 = go.Scatterpolar(
      r = df[df['Country'] == 'Slovakia'].loc[:,"Voice & Accountability":].values[0], # данные на шкалы 
      theta = col_names, # подписи шкал
      fill = 'toself', # заливка
      name = 'Slovakia',
      marker = dict(color = '#aaf0d1')
    )
    
trace_median= go.Scatterpolar(
      r = df.loc[:,"Voice & Accountability":].median().values,
      theta = col_names,
      fill = 'none',
      name = 'Median',
      marker = dict(color = '#fa8072')
    )

layout = go.Layout(
    title = 'Slovakia',
    template="plotly_dark",
    polar = dict(
    radialaxis = dict(
      visible = True,
      range = [1, 65]
    )
  ),
  showlegend = False
)

fig = go.Figure(data=[trace0, trace_median], layout=layout)
fig.show()
# Out:
# <div>
#
#
#             <div id="3f1e3e65-c4b4-4d88-bd68-d13c7ec6822b" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("3f1e3e65-c4b4-4d88-bd68-d13c7ec6822b")) {
#                     Plotly.newPlot(
#                         '3f1e3e65-c4b4-4d88-bd68-d13c7ec6822b',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Slovakia", "r": [6, 2, 5, 6, 7, 13, 9, 6, 4, 23, 4, 5, 8, 7, 6], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...

# %% [markdown]
# А теперь давайте построим самостоятельно графики для всех наших стран.

# %%
for country in df['Country']:
    trace0 = go.Scatterpolar(
      r = df[df['Country'] == country].loc[:,"Voice & Accountability":].values[0], # данные на шкалы 
      theta = col_names, # подписи шкал
      fill = 'toself', # заливка
      name = country,
      marker = dict(color = '#aaf0d1')
    )
    
    trace_median= go.Scatterpolar(
          r = df.loc[:,"Voice & Accountability":].median().values,
          theta = col_names,
          fill = 'none',
          name = 'Median',
          marker = dict(color = '#fa8072')
        )

    layout = go.Layout(
        title = country,
        template="plotly_dark",
        polar = dict(
        radialaxis = dict(
          visible = True,
          range = [65, 1] # инвертируем шкалу, чтобы данные воспринимались интутивно - 65 теперь в центре, а 1 на перефирии        )
      ),
      showlegend = False
    )

    fig = go.Figure(data=[trace0, trace_median], layout=layout)
    fig.show()
# Out:
# <div>
#
#
#             <div id="345e7d48-7a1d-4d9a-9b5b-09e1d85d010e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("345e7d48-7a1d-4d9a-9b5b-09e1d85d010e")) {
#                     Plotly.newPlot(
#                         '345e7d48-7a1d-4d9a-9b5b-09e1d85d010e',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Slovakia", "r": [6, 2, 5, 6, 7, 13, 9, 6, 4, 23, 4, 5, 8, 7, 6], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="89f8e39e-934d-446e-98c9-421735a37473" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("89f8e39e-934d-446e-98c9-421735a37473")) {
#                     Plotly.newPlot(
#                         '89f8e39e-934d-446e-98c9-421735a37473',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Poland", "r": [3, 3, 6, 4, 3, 5, 3, 5, 1, 5, 10, 2, 6, 13, 3], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="de43ffec-0734-45b4-858c-1ac5987cf224" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("de43ffec-0734-45b4-858c-1ac5987cf224")) {
#                     Plotly.newPlot(
#                         'de43ffec-0734-45b4-858c-1ac5987cf224',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Lithuania", "r": [5, 5, 1, 2, 2, 6, 4, 3, 2, 4, 3, 4, 3, 3, 5], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="70c8fef8-e884-4ed8-be21-6efe0ee445f7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("70c8fef8-e884-4ed8-be21-6efe0ee445f7")) {
#                     Plotly.newPlot(
#                         '70c8fef8-e884-4ed8-be21-6efe0ee445f7',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Latvia", "r": [7, 11, 2, 3, 4, 7, 6, 1, 6, 12, 2, 7, 7, 6, 7], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="680062eb-dfe4-49b0-a35b-61697e8a4b53" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("680062eb-dfe4-49b0-a35b-61697e8a4b53")) {
#                     Plotly.newPlot(
#                         '680062eb-dfe4-49b0-a35b-61697e8a4b53',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Philippines", "r": [29, 48, 22, 28, 35, 33, 37, 38, 45, 17, 27, 52, 65, 23, 29], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="359125fe-d426-46b5-9fa9-5e23d47fe728" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("359125fe-d426-46b5-9fa9-5e23d47fe728")) {
#                     Plotly.newPlot(
#                         '359125fe-d426-46b5-9fa9-5e23d47fe728',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Hungary", "r": [12, 4, 9, 8, 11, 14, 12, 11, 5, 26, 5, 11, 21, 22, 12], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="f4ca0a5e-1f02-4664-bde2-9e4d679203c7" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("f4ca0a5e-1f02-4664-bde2-9e4d679203c7")) {
#                     Plotly.newPlot(
#                         'f4ca0a5e-1f02-4664-bde2-9e4d679203c7',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "India", "r": [19, 52, 23, 43, 20, 29, 24, 52, 54, 7, 61, 45, 39, 21, 19], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="1995f837-0306-4b5c-8163-145b368ce969" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1995f837-0306-4b5c-8163-145b368ce969")) {
#                     Plotly.newPlot(
#                         '1995f837-0306-4b5c-8163-145b368ce969',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Chile", "r": [4, 13, 3, 1, 1, 2, 2, 17, 3, 3, 17, 3, 59, 10, 4], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="335ac38f-55fd-4343-85f9-3f5c205d7e6a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("335ac38f-55fd-4343-85f9-3f5c205d7e6a")) {
#                     Plotly.newPlot(
#                         '335ac38f-55fd-4343-85f9-3f5c205d7e6a',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Malaysia", "r": [41, 18, 4, 7, 6, 8, 10, 4, 14, 1, 24, 19, 32, 52, 41], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
# ...
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="20f75dae-0121-4086-85c7-0477968ea96a" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("20f75dae-0121-4086-85c7-0477968ea96a")) {
#                     Plotly.newPlot(
#                         '20f75dae-0121-4086-85c7-0477968ea96a',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Mozambique", "r": [40, 43, 57, 48, 56, 54, 59, 53, 65, 61, 65, 55, 52, 28, 40], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
# <div>
#
#
#             <div id="5759a76a-d038-4362-910f-b73728a4ab11" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("5759a76a-d038-4362-910f-b73728a4ab11")) {
#                     Plotly.newPlot(
#                         '5759a76a-d038-4362-910f-b73728a4ab11',
#                         [{"fill": "toself", "marker": {"color": "#aaf0d1"}, "name": "Venezuela", "r": [58, 54, 64, 65, 65, 63, 63, 65, 21, 60, 20, 49, 27, 59, 58], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}, {"fill": "none", "marker": {"color": "#fa8072"}, "name": "Median", "r": [33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0, 33.0], "theta": ["Voice & Accountability", "Political Stability", "Govt. Effectiveness", "Regulatory Quality", "Rule of Law", "Control of Corruption", "Corruption percetion", "Ease of Doing Business", "Human Dev. Index", "Global Compet. Index", "Eviron. Performance Index", "Fragile States Index", "UN World Risk Index", "Freedom of the Press Index", "Voice & Accountability"], "type": "scatterpolar"}],
#                         {"polar": {"radialaxis": {"range": [1, 65], "visible": true}}, "showlegend": false, "template": {"data": {"bar": [{"error_x": {"color": "#f2f5fa"}, "error_y": {"color": "#f2f5fa"}, "marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "rgb(17,17,17)", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "baxis": {"endlinecolor": "#A2B1C6", "gridcolor": "#506784", "linecolor": "#506784", "minorgridcolor": "#506784", "startlinecolor": "#A2B1C6"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "scatter": [{"marker": {"line": {"color": "#283442"}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"line": {"color": "#283442"}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolargl"}], "scatterternary" ...
